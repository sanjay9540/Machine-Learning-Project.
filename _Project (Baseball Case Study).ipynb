# %% [markdown]
# # PROJECT (BASEBALL CASE STUDY)

# %%
from PIL import Image
#for displaying the image using matplotlib.
import matplotlib.pyplot as plt 
#Define the image file path using a raw string (prefix with "r").
image_path="C:/Users/sanja/Downloads/megan-ellis-3y25jcL2o-U-unsplash.jpg"
# open an image file
img=Image.open(image_path)
# Display the image using matplotlib
plt.imshow(img)
#Turn off axes for image display.
plt.axis('off')
plt.show()

# %% [markdown]
# # Import library.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Datasets

# %%
df=pd.read_csv("C:\jan20\Baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# In these datasets my target variable is number of predicted wine(w).

# %%
# show the top 5 data in the datasets.
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# show the bottum 5 data in the datasets.
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# show the columns
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# we can see rows and columns number.
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Here we can see that 30 rows and 17 columns in this datasets.

# %%
print("The Dimenssions of Datasets:",df.shape)
print("The columns of the datasets:",df.columns)
# Out:
# The Dimenssions of Datasets: (30, 17)
# The columns of the datasets: Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# Checking the data types.
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# seprating numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical_col :",numerical_col)
# Out:
# Numerical_col : ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']

# %%
# checking the null value.
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Here we can see that there is no null value presents in these datasets.

# %%
#check null value using heatmap.
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Count values of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64
#
#
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64
#
#
# AB
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
# check unique values in each columns
df.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %%
df["W"].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df["R"].unique()
# Out:
# array([724, 696, 669, 622, 689, 891, 764, 713, 644, 748, 751, 729, 661,
#        656, 694, 647, 697, 655, 640, 683, 703, 613, 573, 626, 667, 720,
#        650, 737], dtype=int64)

# %%
df["AB"].unique()
# Out:
# array([5575, 5467, 5439, 5533, 5605, 5509, 5567, 5485, 5640, 5511, 5459,
#        5417, 5544, 5600, 5484, 5631, 5491, 5480, 5571, 5527, 5428, 5463,
#        5420, 5529, 5385, 5565, 5649, 5457, 5572], dtype=int64)

# %%
df["H"].unique()
# Out:
# array([1497, 1349, 1395, 1381, 1515, 1480, 1397, 1370, 1383, 1495, 1419,
#        1363, 1331, 1379, 1405, 1386, 1462, 1341, 1378, 1382, 1351, 1420,
#        1361, 1374, 1346, 1486, 1494, 1324, 1479], dtype=int64)

# %%
df["2B"].unique()
# Out:
# array([300, 277, 303, 260, 289, 308, 272, 246, 278, 294, 279, 243, 262,
#        288, 292, 274, 257, 295, 265, 236, 251, 263], dtype=int64)

# %%
df["3B"].unique()
# Out:
# array([42, 44, 29, 27, 49, 17, 19, 20, 32, 33, 26, 21, 22, 46, 39, 30, 34,
#        13, 40, 18, 37, 48, 36], dtype=int64)

# %%
df["HR"].unique()
# Out:
# array([139, 156, 141, 136, 151, 232, 212, 217, 167, 161, 172, 230, 176,
#        198, 146, 137, 140, 171, 145, 177, 120, 100, 130, 187, 154, 148,
#        186], dtype=int64)

# %%
df["BB"].unique()
# Out:
# array([383, 439, 533, 404, 455, 570, 554, 418, 436, 478, 503, 486, 435,
#        475, 506, 461, 567, 412, 496, 488, 539, 375, 471, 387, 563, 457,
#        490, 426, 388], dtype=int64)

# %%
df["SO"].unique()
# Out:
# array([ 973, 1264, 1157, 1231, 1259, 1151, 1227, 1331, 1310, 1148, 1233,
#        1392, 1150, 1336, 1119, 1267, 1322, 1518, 1299, 1255, 1290, 1344,
#        1107, 1274, 1258, 1159, 1312, 1327, 1283], dtype=int64)

# %%
df["CG"].unique()
# Out:
# array([ 2, 11,  7,  3,  0,  1,  5,  6,  4], dtype=int64)

# %%
df["SHO"].unique()
# Out:
# array([ 8, 12, 10,  9,  4, 13, 15, 21,  7, 14, 18,  6], dtype=int64)

# %%
df["SB"].unique()
# Out:
# array([104,  70,  86,  68,  83,  88,  63,  44,  87,  71, 101, 121,  52,
#         69,  78,  98,  95,  84, 134,  51,  57, 112,  59,  93, 132,  82,
#         97], dtype=int64)

# %%
df["RA"].unique()
# Out:
# array([641, 700, 640, 701, 803, 670, 698, 693, 642, 753, 733, 618, 675,
#        726, 729, 525, 596, 608, 737, 754, 613, 635, 678, 760, 809, 595,
#        627, 713, 731, 844], dtype=int64)

# %%
df["ER"].unique()
# Out:
# array([601, 653, 584, 643, 746, 609, 652, 646, 604, 694, 680, 572, 630,
#        677, 664, 478, 532, 546, 682, 700, 557, 577, 638, 698, 749, 553,
#        597, 659, 655, 799], dtype=int64)

# %%
df["SV"].unique()
# Out:
# array([56, 45, 38, 37, 35, 34, 48, 43, 60, 40, 39, 46, 28, 62, 54, 50, 41,
#        44, 47, 36], dtype=int64)

# %%
df["E"].unique()
# Out:
# array([ 88,  86,  79, 101,  93,  77,  95,  97, 119,  85,  94, 126,  96,
#        122, 111, 116,  90, 117,  75,  78,  92], dtype=int64)

# %% [markdown]
# ## Visualization the datasets

# %%
# visualization the number of winnings.
ax=sns.countplot(x='W',data=df)
print(df['W'].value_counts())
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64

# %%
#Assuming df is your dataframe and it has colun named 'Runs
runs_counts=df['R'].value_counts()

plt.figure(figsize=(20,18))
runs_counts.plot(kind='bar',color='Skyblue')
plt.title('Distribution of R')
plt.xlabel('R')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
#Assuming is your dataframe and it has column named "AB".
job_counts=df["AB"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='green')
plt.title('Distribution of AB')
plt.xlabel('AB')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'H'.
job_counts=df["H"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='blue')
plt.title('Distribution of H')
plt.xlabel('H')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named '2B'.
job_counts=df["2B"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='blue')
plt.title('Distribution of H')
plt.xlabel('2B')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named '3B'.
job_counts=df["3B"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='yellow')
plt.title('Distribution of H')
plt.xlabel('3B')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'BB'.
job_counts=df["BB"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='blue')
plt.title('Distribution of H')
plt.xlabel('BB')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'SO'.
job_counts=df["SO"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='red')
plt.title('Distribution of H')
plt.xlabel('SO')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'SB'.
job_counts=df["SB"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='black')
plt.title('Distribution of H')
plt.xlabel('SB')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'RA'.
job_counts=df["RA"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='yellowgreen')
plt.title('Distribution of H')
plt.xlabel('RA')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'ER'.
job_counts=df["ER"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='yellow')
plt.title('Distribution of H')
plt.xlabel('ER')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'ERA'.
job_counts=df["ERA"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='blue')
plt.title('Distribution of H')
plt.xlabel('ERA')
plt.ylabel('count')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'SHO'.
job_counts=df["SHO"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='green')
plt.title('Distribution of H')
plt.xlabel('SO')
plt.ylabel('count')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'SV'.
job_counts=df["SV"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='red')
plt.title('Distribution of H')
plt.xlabel('SV')
plt.ylabel('count')
plt.xticks(rotation=0)# Rotate x-axis labels if needed
plt.show()

# %%
# assuming df is your dataframe and it has a column named 'E'.
job_counts=df["E"].value_counts()

plt.figure(figsize=(20,18))
job_counts.plot(kind='bar',color='skyblue')
plt.title('Distribution of H')
plt.xlabel('E')
plt.ylabel('count')
plt.xticks(rotation=0)# Rotate x-axis labels if needed
plt.show()

# %%
#visualize the number of cg
ax=sns.countplot(x='CG',data=df)
print(df['CG'].value_counts())
# Out:
# CG
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='E',data=df)
print(df['E'].value_counts())
# Out:
# E
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=df['SHO'],color='blue')
plt.title("Distribution of SHO")
plt.xlabel('SHO')
plt.ylabel('Frequency')
plt.grid(True)
plt.xticks(rotation=90) # Rotate x-axis labels if needed
plt.show()

# %% [markdown]
#  ## Relational Analysis

# %%
# W column and R
plt.figure(figsize=(10,8)) # Adjust the figure size as needed

# Create the bar plot
sns.barplot(x="W",y="R",data=df)

#set labels and title
plt.title('Relationship between W and R')
plt.xlabel("W")
plt.ylabel("R")
plt.show()

# %%
# W and AB
plt.figure(figsize=(8,6))


# Create the bar plot
sns.barplot(x='W',y='AB',data=df)

#set label and title 
plt.title('Relation between w and AB')
plt.xlabel('W')
plt.ylabel('AB')
plt.show()  #show the plot

# %%
#  Relation of W and H.
plt.figure(figsize=(6,4))

# Create the bar plot
sns.barplot(x='W',y='H',data=df)

#set labels and title
plt.xlabel('W')
plt.ylabel('H')
plt.title('Relation between W and H')

#show the plot
plt.show()

# %%
#Relation of W and 2B
plt.figure(figsize=(8,6))

#Create the barplot
sns.barplot(x='W',y='2B',data=df)

#Set label and title
plt.xlabel('W')
plt.ylabel('2B')
plt.title('Realation between W and 2B')

# show the plot
plt.show()

# %%
#Relation of W and 3B
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='3B',data=df)

# set label and title.
plt.title('Relation between W and 3B')
plt.xlabel('W')
plt.ylabel('3B')

#show trhe plot
plt.show()

# %%
#Relation of W and HR
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='HR',data=df)

# set label and title.
plt.title('Relation between W and HR')
plt.xlabel('W')
plt.ylabel('HR')

#show trhe plot
plt.show()

# %%
#Relation of W and BB
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='3B',data=df)

# set label and title.
plt.title('Relation between W and BB')
plt.xlabel('W')
plt.ylabel('BB')

#show trhe plot
plt.show()

# %%
#Relation of W and SO
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='SO',data=df)

# set label and title.
plt.title('Relation between W and SO')
plt.xlabel('W')
plt.ylabel('SO')

#show trhe plot
plt.show()

# %%
#Relation of W and SB
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='SB',data=df)

# set label and title.
plt.title('Relation between W and SB')
plt.xlabel('W')
plt.ylabel('SB')

#show trhe plot
plt.show()

# %%
#Relation of W and RA
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='RA',data=df)

# set label and title.
plt.title('Relation between W and RA')
plt.xlabel('W')
plt.ylabel('RA')

#show trhe plot
plt.show()

# %%
#Relation of W and ER
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='ER',data=df)

# set label and title.
plt.title('Relation between W and ER')
plt.xlabel('W')
plt.ylabel('ER')

#show trhe plot
plt.show()

# %%
#Relation of W and ERA
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='ERA',data=df)

# set label and title.
plt.title('Relation between W and ERA')
plt.xlabel('W')
plt.ylabel('ERA')

#show trhe plot
plt.show()

# %%
#Relation of W and CG
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='CG',data=df)

# set label and title.
plt.title('Relation between W and CG')
plt.xlabel('W')
plt.ylabel('CG')

#show trhe plot
plt.show()

# %%
#Relation of W and SHO
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='SHO',data=df)

# set label and title.
plt.title('Relation between W and SHO')
plt.xlabel('W')
plt.ylabel('SHO')

#show trhe plot
plt.show()

# %%
#Relation of W and SV
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='SV',data=df)

# set label and title.
plt.title('Relation between W and SV')
plt.xlabel('W')
plt.ylabel('SV')

#show trhe plot
plt.show()

# %%
#Relation of W and E
plt.figure(figsize=(10,8))

#Create the barplot
sns.barplot(x='W',y='E',data=df)

# set label and title.
plt.title('Relation between W and E')
plt.xlabel('W')
plt.ylabel('E')

#show trhe plot
plt.show()

# %% [markdown]
# ### check the data distributed in each columns.

# %%
plt.figure(figsize=(25,30),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber <=18:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# ### Check the outliers

# %%
num_numerical_cols=len(numerical_col)
num_rows=5 #Number of rows in the subplot grid
num_cols=4 #Number of columns in the subplot grid
total_subplots=num_rows*num_cols

#Create a new figure and set its size
plt.figure(figsize=(20,16),facecolor='white') #Adjust the size as needed

#Iterate over numerical columns and create subplot for boxplot
plotnumber=1
for col in numerical_col:
    if plotnumber <= total_subplots:
        #Create subplot at the specified position
        ax=plt.subplot(num_rows,num_cols,plotnumber)
        
        # plot boxplot for the current column using seaborn
        sns.boxplot(x=df[col],palette='Set2_r',ax=ax)
        
        #Customize subplot labels and ticks
        plt.xlabel(col,fontsize=15)
        plt.ylabel("") #Clear y-axis label
        plt.xticks(rotation=0,fontsize=10)
        plt.yticks(fontsize=10)
        
        plotnumber+=1

#Adjust layout to prevent  overlap and improve readability
plt.tight_layout()
plt.show() #Display the figure with subplots

# %% [markdown]
# only five columns contains some outliers

# %% [markdown]
# ## Removing Outliers:

# %% [markdown]
# ### Using Zscore method

# %%
#Feature having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# So,I have removed outliers by using Zscore.

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# There are 29 rows and 17 columns of shape of new dataset after removing outliers.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns in old dataset.

# %%
#Checking datyaloss
Dataloss=(((30-29)/30)*100)

# %%
Dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# So, I can see dataloss in zscore method after removing outliers of 3.33% which is less than 10%

# %% [markdown]
# ## Checking for Skewness

# %%
# Here all columns data types is numerical so no convert.
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# I can see that there is skewness in Hits(H),Completed games(CG),Shoutouts(SHO),Saves(SV),Errors(E).

# %% [markdown]
# ## Removing Skewness:

# %%
# List of skewned features
skew_features=['H','CG','SHO','SV','E']

# %%
#Removing skewness in H using log1p
df_new['H']=np.log1p(df_new['H'])

# %%
from sklearn.preprocessing import PowerTransformer
scaler=PowerTransformer(method='yeo-johnson')
'''
parameters:
method= 'box_cox'or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod= 'box_cox'or 'yeo-johnson'\n"

# %% [markdown]
# I have removed the skewness in E by using yeo-johnson method.

# %%
#Removing skewness using yeo-johnson
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
#Checking skewness after removing skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# After trying to remove skewness in H using yeo-johnson method i got 0.0 skewness.

# %%
#After removing let's check how the data has been distributed in each column of skew_features.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_features]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# By seeing the plot i can say that skewness is removed.

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %% [markdown]
# x=Feature and y=Target

# %% [markdown]
# ## Scaling Data using StandardScaler:

# %%
#Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
ssc=StandardScaler()
X = pd.DataFrame(ssc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.307098 -0.787002
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.307098  0.236737
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.011315 -0.252844
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.264463 -0.513555
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.264463  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# ...

# %% [markdown]
# ## Variance inflation factor:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.112342        R
# 1      20.237195       AB
# 2      10.114607        H
# 3       3.528059       2B
# 4       3.227808       3B
# 5       8.736960       HR
# 6       3.324550       BB
# 7       2.811546       SO
# 8       1.955254       SB
# 9     200.826177       RA
# 10   2079.420586       ER
# 11   1614.529449      ERA
# 12      2.912414       CG
# 13      3.274913      SHO
# 14      5.914692       SV
# 15      2.341746        E

# %% [markdown]
# VIF values i can say that multicolinearity exists in RA,ER,ERA. So let me drop RA and ER columns to avoid multicolinearity.

# %%
# Droping ER
X=X.drop(["ER"],axis=1)

# %%
X.head(10)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
# 5  1.856900  0.716535 -0.051906 -0.093474 -1.266972  1.743939  1.643442
# 6  0.712585 -0.447345 -0.553131 -1.625627 -1.167936  1.915843 -0.885522
# 7 -0.835605 -0.447345 -0.310580  0.260100  0.020490  0.196801 -0.550807
# 8  1.497899  1.752672  1.689389  1.202964  0.119526 -0.009484  0.230197
# 9  1.565212 -0.078310  0.349394  0.319029  0.020490  0.368705  0.695081
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.307098 -0.787002  1.532753
# ...

# %% [markdown]
# I can see Dependent variables after removing multicolinearity.

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.069116        R
# 1       7.791456       AB
# 2       9.340727        H
# 3       3.227862       2B
# 4       3.125190       3B
# 5       7.474108       HR
# 6       3.323583       BB
# 7       2.786186       SO
# 8       1.787493       SB
# 9     142.535647       RA
# 10    141.460079      ERA
# 11      2.536866       CG
# 12      3.136960      SHO
# 13      2.630293       SV
# 14      2.272337        E

# %% [markdown]
# Still VIF is high for 2 columns so let me drop ERA.

# %%
X=X.drop(['ERA'],axis=1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.019438        R
# 1       5.210230       AB
# 2       7.728111        H
# 3       3.165732       2B
# 4       2.981242       3B
# 5       6.168639       HR
# 6       3.053363       BB
# 7       2.287734       SO
# 8       1.773119       SB
# 9       4.759240       RA
# 10      2.522962       CG
# 11      3.121855      SHO
# 12      2.606434       SV
# 13      2.239918        E

# %% [markdown]
# Multicolinearity issue is solved

# %% [markdown]
# ## Splitting the data for training and testing:

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Let find the best random state:

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9768383015216393
# At random state0, The test accuracy is :-0.49963681285930206
#
#
# At random state1, The training accuracy is :-0.9762285427209907
# At random state1, The test accuracy is :-0.1856575667552426
#
#
# At random state2, The training accuracy is :-0.9638255316870876
# At random state2, The test accuracy is :--0.26799016473915627
#
#
# At random state3, The training accuracy is :-0.9677990948927813
# At random state3, The test accuracy is :-0.677669778666316
#
#
# At random state4, The training accuracy is :-0.9680569379679668
# At random state4, The test accuracy is :-0.7641316816582383
#
#
# At random state5, The training accuracy is :-0.9612472010423034
# At random state5, The test accuracy is :-0.6051495407609998
#
#
# At random state6, The training accuracy is :-0.9723763056746938
# At random state6, The test accuracy is :-0.7504731543294977
#
#
# At random state7, The training accuracy is :-0.9610245315460944
# ...

# %% [markdown]
# I can see random state=99 giving highest accuracy,choosing that as random state.

# %%
#Splitting the data into 78% training and 22% testing

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 16)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 16)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
#  ## Model Building:

# %% [markdown]
# ## Regression Algorithms:

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# ## 1)Linear Regression:

# %%
from sklearn.linear_model import LinearRegression

LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9633011594527366

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 27.07787872028507
# MAE: 4.9990723975686615
# r2_score: 0.8702723798743071

# %% [markdown]
# LR is giving me 88% r2_score.

# %% [markdown]
# ## 2)SGD:

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
# Out:
# R2_score: -2.23000277204616e+27
# mae: 3.0255221282781374e+29
# mae: 422589058528675.0

# %% [markdown]
# SGD is giving me 90% r2_score.

# %% [markdown]
# ## 3)Lasso Regressor:

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8162585359689943
# mse: 24.92884189547195
# mae: 4.824282278813712
# rmse: 4.992879118852363

# %% [markdown]
# Lasso is giving me 90%r2_score.

# %% [markdown]
# ## 4)Ridge Regressor:

# %%
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(x_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'saga'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8517943203241294
# mse: 20.107578744595674
# mae: 4.278828003576983
# rmse: 4.484147493626372

# %% [markdown]
# Ridge is giving 76%r2_score.

# %% [markdown]
# ## Cross Validation:

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model,x,y):
    rmse =-(cross_val_score(model,x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)

models = [LinearRegression(),
         Ridge(),
         SVR(kernel='linear'),
         SVR(kernel='poly'),
         SVR(kernel='rbf'),
         RandomForestRegressor(),
         DecisionTreeRegressor(),
         GradientBoostingRegressor(),]

names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : 33.227142, 22.206678
# R   : 32.549049, 32.609656
# svr   : 58.165562, 34.299786
# svr_p   : 111.891643, 79.768934
# svr_r   : 112.275451, 79.777668
# RF   : 39.864027, 24.023091
# DTR   : 70.216667, 45.490539
# GBR   : 47.569624, 31.099844

# %% [markdown]
# According to all metrics score selecting the linearRegression as final model

# %% [markdown]
# ## Hyper Parameter Tuning:

# %%
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, StackingClassifier

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000],
            'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
 GVC.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 GVC.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
# ...

# %%
 GVC.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 GVC.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# I can see best parameters.

# %%
Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=4, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[138], line 2
#       1 Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=4, selection="random", tol=1000)
# ----> 2 Final_mod.fit(x_train,y_train)
#       3 pred=Final_mod.predict(x_test)
#       4 print('R2_Score:',r2_score(y_test,pred)*100)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:892, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#     856 def fit(self, X, y, sample_weight=None, check_input=True):
#     857     """Fit model with coordinate descent.
#     858
#     859     Parameters
#    (...)
#     890     initial data in memory directly using that format.
#     891     """
# --> 892     self._validate_params()
#     894     if self.alpha == 0:
#     895         warnings.warn(
#     896             "With alpha=0, this algorithm does not converge "
# ...

# %% [markdown]
# After tuning i got 79.48% accuracy which is good.

# %% [markdown]
# ## Saving the model:

# %%
#Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %% [markdown]
# I have saved my model using joblib.

# %% [markdown]
# ## Predictions:

# %%
#Loading the saved model
model=joblib.load("BaseballCaseStudy.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[159], line 5
#       2 model=joblib.load("BaseballCaseStudy.pkl")
#       4 #Prediction
# ----> 5 prediction = model.predict(x_test)
#       6 prediction
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1070, in ElasticNet._decision_function(self, X)
#    1058 def _decision_function(self, X):
#    1059     """Decision function of the linear model.
#    1060
#    1061     Parameters
#    (...)
#    1068         The predicted decision function.
#    1069     """
# ...

# %% [markdown]
# These are predicted values

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1070, in ElasticNet._decision_function(self, X)
#    1058 def _decision_function(self, X):
#    1059     """Decision function of the linear model.
#    1060
#    1061     Parameters
#    (...)
#    1068         The predicted decision function.
#    1069     """
# -> 1070     check_is_fitted(self)
# ...

# %% [markdown]
# Both original and predicted values are almost equal.

# %% [markdown]
# ### COMPLETED THE BASEBALLCASE STUDY
